# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702-Artificial-Intelligence/blob/main/family_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Family Tree

father = {
    "arun": "kumar",
    "ravi": "arun"
}

mother = {
    "arun": "meena",
    "ravi": "sita"
}

def get_father(person):
    if person in father:
        print(person, "is the child of", father[person])

def get_mother(person):
    if person in mother:
        print(person, "is the child of", mother[person])

person = input("Enter person's name: ").lower()

get_father(person)
get_mother(person)
# Out:
# Enter person's name: arun
# arun is the child of kumar
# arun is the child of meena
