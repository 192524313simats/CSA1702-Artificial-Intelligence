# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702-Artificial-Intelligence/blob/main/fruit_and_its_colour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fruit and its Color

fruits = [
    ("apple", "red"),
    ("banana", "yellow"),
    ("orange", "orange"),
    ("grapes", "green"),
    ("mango", "yellow"),
    ("watermelon", "green")
]

fruit = input("Enter fruit: ").lower()

found = False

for name, color in fruits:
    if name == fruit:
        print("Color =", color)
        found = True

if not found:
    print("Fruit not found.")
# Out:
# Enter fruit: mango
# Color = yellow
