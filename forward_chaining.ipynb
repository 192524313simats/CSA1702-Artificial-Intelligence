# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702-Artificial-Intelligence/blob/main/forward_chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Forward Chaining

facts = {"rain"}

rules = [
    ({"rain"}, "wet_ground"),
    ({"wet_ground"}, "slippery"),
    ({"slippery"}, "dangerous")
]

def forward_chaining(facts, rules):
    facts = set(facts)

    changed = True

    while changed:
        changed = False

        for conditions, conclusion in rules:
            if conditions.issubset(facts) and conclusion not in facts:
                facts.add(conclusion)
                print("Derived:", conclusion)
                changed = True

    return facts


# Query
result = forward_chaining(facts, rules)

print("\nFinal Facts:")
print(result)
# Out:
# Derived: wet_ground
# Derived: slippery
# Derived: dangerous
#
# Final Facts:
# {'dangerous', 'slippery', 'rain', 'wet_ground'}
