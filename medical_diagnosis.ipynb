# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702-Artificial-Intelligence/blob/main/medical_diagnosis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Medical Diagnosis

symptoms = {
    "fever": False,
    "cough": False,
    "body_pain": False,
    "sore_throat": False
}

# Input symptoms
for symptom in symptoms:
    answer = input("Do you have " + symptom + "? (yes/no): ")
    symptoms[symptom] = answer.lower() == "yes"

# Diagnosis rules
if symptoms["fever"] and symptoms["body_pain"]:
    print("\nDiagnosis: Flu")
elif symptoms["cough"] and symptoms["sore_throat"]:
    print("\nDiagnosis: Common Cold")
elif symptoms["fever"] and symptoms["cough"]:
    print("\nDiagnosis: Possible Infection")
else:
    print("\nDiagnosis: No clear diagnosis")
# Out:
# Do you have fever? (yes/no): yes
# Do you have cough? (yes/no): yes
# Do you have body_pain? (yes/no): no
# Do you have sore_throat? (yes/no): yes
#
# Diagnosis: Common Cold
