# %% [markdown]
# <a href="https://colab.research.google.com/github/192524313simats/CSA1702-Artificial-Intelligence/blob/main/birds_can_fly_or_not.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bird Can Fly or Not

birds = {
    "eagle": True,
    "sparrow": True,
    "parrot": True,
    "penguin": False,
    "ostrich": False
}

bird = input("Enter bird name: ").lower()

if bird in birds:
    if birds[bird]:
        print(bird, "can fly.")
    else:
        print(bird, "cannot fly.")
else:
    print("Bird not found.")
# Out:
# Enter bird name: parrot
# parrot can fly.
